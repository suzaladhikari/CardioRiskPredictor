# %%
import pandas as pd 
import numpy as np

# %%
### Since the cleaned.csv has alot of biasness in the data, we will fix that using the random sampling 
data = pd.read_csv('../dataCleaning/cleaned.csv')
data.head(5)
# Out:
#    Unnamed: 0 General_Health                  Checkup Exercise Heart_Disease  \
# 0           0           Poor  Within the past 2 years       No            No
# 1           1      Very Good     Within the past year       No           Yes
# 2           2      Very Good     Within the past year      Yes            No
# 3           3           Poor     Within the past year      Yes           Yes
# 4           4           Good     Within the past year       No            No
#
#   Skin_Cancer Other_Cancer Depression Diabetes Arthritis  ... Age_Category  \
# 0          No           No         No       No       Yes  ...        70-74
# 1          No           No         No      Yes        No  ...        70-74
# 2          No           No         No      Yes        No  ...        60-64
# 3          No           No         No      Yes        No  ...        75-79
# 4          No           No         No       No        No  ...          80+
#
# ...

# %%
##Lets see the total counts of people with Heart Disease and without Heart Disease 
print(data['Heart_Disease'].value_counts(normalize=True) *100)
##As seen there are 91% of total No cases whereas only 8.08% of the Yes cases, which causes Biasness
# Out:
# Heart_Disease
# No     91.91495
# Yes     8.08505
# Name: proportion, dtype: float64

# %%
onlyYes = data[data['Heart_Disease'] == 'Yes']
onlyNo = data[data['Heart_Disease'] == 'No']
sampleOne = onlyNo.sample(n = 80000, replace = True)
sampleTwo = onlyYes.sample(n = 80000, replace = True)
merged = pd.concat([sampleOne,sampleTwo])
onlyCategorical = merged.select_dtypes('object')
print(onlyCategorical.columns)

for every in onlyCategorical.columns:
    print(f"The normalize value of {every} column is {onlyCategorical[every].value_counts(normalize=True)}")
# Out:
# Index(['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer',
#        'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex',
#        'Age_Category', 'Smoking_History'],
#       dtype='object')
# The normalize value of General_Health column is General_Health
# Good         0.325381
# Very Good    0.282850
# Fair         0.187188
# Excellent    0.119025
# Poor         0.085556
# Name: proportion, dtype: float64
# The normalize value of Checkup column is Checkup
# Within the past year       0.834331
# Within the past 2 years    0.093750
# Within the past 5 years    0.038962
# 5 or more years ago        0.029337
# Never                      0.003619
# Name: proportion, dtype: float64
# The normalize value of Exercise column is Exercise
# Yes    0.712275
# No     0.287725
# Name: proportion, dtype: float64
# The normalize value of Heart_Disease column is Heart_Disease
# No     0.5
# Yes    0.5
# Name: proportion, dtype: float64
# ...

# %% [markdown]
# ### Since we have achieved equality in the distribution of the data, we can now change it to the csv file and prepare the model

# %%
merged.to_csv('forModel.csv')
